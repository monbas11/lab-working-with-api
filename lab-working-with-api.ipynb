# %%
import requests

# %%
url = "https://aerodatabox.p.rapidapi.com/airports/search/term"
    
querystring = {"q":"madrid","limit":"10"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "9613ca6ca5msh62659872159916fp1a0a2cjsndd9a3e6ff324"
    }


response = requests.get(url, headers=headers, params=querystring)

result = response.json()
result
# Out:
# {'searchBy': 'madrid',
#  'count': 4,
#  'items': [{'icao': 'LEMD',
#    'iata': 'MAD',
#    'name': 'Madrid Adolfo Suárez –Barajas',
#    'shortName': 'Adolfo Suárez –Barajas',
#    'municipalityName': 'Madrid',
#    'location': {'lat': 40.4936, 'lon': -3.56676},
#    'countryCode': 'ES'},
#   {'icao': 'LECU',
#    'iata': 'ECV',
#    'name': 'Madrid Cuatro Vientos',
#    'shortName': 'Cuatro Vientos',
#    'municipalityName': 'Madrid',
#    'location': {'lat': 40.3707, 'lon': -3.78514},
#    'countryCode': 'ES'},
#   {'icao': 'LETO',
#    'iata': 'TOJ',
#    'name': 'Madrid Torrejón',
#    'shortName': 'Torrejón',
#    'municipalityName': 'Madrid',
#    'location': {'lat': 40.4967, 'lon': -3.445869},
#    'countryCode': 'ES'},
#   {'icao': 'MMIA',
#    'iata': 'CLQ',
#    'name': 'Colima Licenciado Miguel de la Madrid',
#    'shortName': 'Licenciado Miguel de la Madrid',
#    'municipalityName': 'Colima',
#    'location': {'lat': 19.277, 'lon': -103.577},
#    'countryCode': 'MX'}]}

# %%
import pandas as pd

# Normalize the response

r_json = response.json()
r_json['items']
# Out:
# [{'icao': 'LEMD',
#   'iata': 'MAD',
#   'name': 'Madrid Adolfo Suárez –Barajas',
#   'shortName': 'Adolfo Suárez –Barajas',
#   'municipalityName': 'Madrid',
#   'location': {'lat': 40.4936, 'lon': -3.56676},
#   'countryCode': 'ES'},
#  {'icao': 'LECU',
#   'iata': 'ECV',
#   'name': 'Madrid Cuatro Vientos',
#   'shortName': 'Cuatro Vientos',
#   'municipalityName': 'Madrid',
#   'location': {'lat': 40.3707, 'lon': -3.78514},
#   'countryCode': 'ES'},
#  {'icao': 'LETO',
#   'iata': 'TOJ',
#   'name': 'Madrid Torrejón',
#   'shortName': 'Torrejón',
#   'municipalityName': 'Madrid',
#   'location': {'lat': 40.4967, 'lon': -3.445869},
#   'countryCode': 'ES'},
#  {'icao': 'MMIA',
#   'iata': 'CLQ',
#   'name': 'Colima Licenciado Miguel de la Madrid',
#   'shortName': 'Licenciado Miguel de la Madrid',
#   'municipalityName': 'Colima',
#   'location': {'lat': 19.277, 'lon': -103.577},
#   'countryCode': 'MX'}]

# %%
pd.json_normalize(r_json['items'])
# Out:
#    icao iata                                   name  \
# 0  LEMD  MAD          Madrid Adolfo Suárez –Barajas
# 1  LECU  ECV                  Madrid Cuatro Vientos
# 2  LETO  TOJ                        Madrid Torrejón
# 3  MMIA  CLQ  Colima Licenciado Miguel de la Madrid
#
#                         shortName municipalityName countryCode  location.lat  \
# 0          Adolfo Suárez –Barajas           Madrid          ES       40.4936
# 1                  Cuatro Vientos           Madrid          ES       40.3707
# 2                        Torrejón           Madrid          ES       40.4967
# 3  Licenciado Miguel de la Madrid           Colima          MX       19.2770
#
#    location.lon
# 0     -3.566760
# 1     -3.785140
# 2     -3.445869
# 3   -103.577000

# %%
querystring = {"q":"london","limit":"10"}

response = requests.request("GET", url, headers=headers, params=querystring)
items = response.json()
items
# Out:
# {'searchBy': 'london',
#  'count': 10,
#  'items': [{'icao': 'CYXU',
#    'iata': 'YXU',
#    'name': 'London ',
#    'shortName': 'London',
#    'municipalityName': 'London',
#    'location': {'lat': 43.0356, 'lon': -81.1539},
#    'countryCode': 'CA'},
#   {'icao': 'EGGW',
#    'iata': 'LTN',
#    'name': 'London Luton',
#    'shortName': 'Luton',
#    'municipalityName': 'London',
#    'location': {'lat': 51.8747, 'lon': -0.368333},
#    'countryCode': 'GB'},
#   {'icao': 'EGKK',
#    'iata': 'LGW',
#    'name': 'London Gatwick',
#    'shortName': 'Gatwick',
#    'municipalityName': 'London',
#    'location': {'lat': 51.1481, 'lon': -0.190277},
#    'countryCode': 'GB'},
#   {'icao': 'EGLC',
#    'iata': 'LCY',
#    'name': 'London City',
#    'shortName': 'City',
#    'municipalityName': 'London',
#    'location': {'lat': 51.5053, 'lon': 0.055277},
#    'countryCode': 'GB'},
#   {'icao': 'EGLL',
#    'iata': 'LHR',
#    'name': 'London Heathrow',
#    'shortName': 'Heathrow',
#    'municipalityName': 'London',
#    'location': {'lat': 51.4706, 'lon': -0.461941},
#    'countryCode': 'GB'},
#   {'icao': 'EGSS',
#    'iata': 'STN',
#    'name': 'London Stansted',
#    'shortName': 'Stansted',
#    'municipalityName': 'London',
#    'location': {'lat': 51.885, 'lon': 0.234999},
#    'countryCode': 'GB'},
#   {'icao': 'EGKB',
#    'iata': 'BQH',
#    'name': 'London Biggin Hill',
#    'shortName': 'Biggin Hill',
#    'municipalityName': 'London',
#    'location': {'lat': 51.3308, 'lon': 0.032499},
#    'countryCode': 'GB'},
#   {'icao': 'EGWU',
#    'iata': 'NHT',
#    'name': 'London RAF Northolt',
#    'shortName': 'RAF Northolt',
#    'municipalityName': 'London',
#    'location': {'lat': 51.553, 'lon': -0.418166},
#    'countryCode': 'GB'},
#   {'icao': 'FAEL',
#    'iata': 'ELS',
#    'name': 'East London Ben Schoeman',
#    'shortName': 'Ben Schoeman',
#    'municipalityName': 'East London',
#    'location': {'lat': -33.0356, 'lon': 27.8259},
#    'countryCode': 'ZA'},
#   {'icao': 'KGON',
#    'iata': 'GON',
#    'name': 'Groton (New London) Groton New London',
#    'shortName': 'Groton New London',
#    'municipalityName': 'Groton (New London)',
#    'location': {'lat': 41.3301, 'lon': -72.0451},
#    'countryCode': 'US'}]}

# %%
import pandas as pd

# Normalize the response

r_json = response.json()
r_json['items']
# Out:
# [{'icao': 'CYXU',
#   'iata': 'YXU',
#   'name': 'London ',
#   'shortName': 'London',
#   'municipalityName': 'London',
#   'location': {'lat': 43.0356, 'lon': -81.1539},
#   'countryCode': 'CA'},
#  {'icao': 'EGGW',
#   'iata': 'LTN',
#   'name': 'London Luton',
#   'shortName': 'Luton',
#   'municipalityName': 'London',
#   'location': {'lat': 51.8747, 'lon': -0.368333},
#   'countryCode': 'GB'},
#  {'icao': 'EGKK',
#   'iata': 'LGW',
#   'name': 'London Gatwick',
#   'shortName': 'Gatwick',
#   'municipalityName': 'London',
#   'location': {'lat': 51.1481, 'lon': -0.190277},
#   'countryCode': 'GB'},
#  {'icao': 'EGLC',
#   'iata': 'LCY',
#   'name': 'London City',
#   'shortName': 'City',
#   'municipalityName': 'London',
#   'location': {'lat': 51.5053, 'lon': 0.055277},
#   'countryCode': 'GB'},
#  {'icao': 'EGLL',
#   'iata': 'LHR',
#   'name': 'London Heathrow',
#   'shortName': 'Heathrow',
#   'municipalityName': 'London',
#   'location': {'lat': 51.4706, 'lon': -0.461941},
#   'countryCode': 'GB'},
#  {'icao': 'EGSS',
#   'iata': 'STN',
#   'name': 'London Stansted',
#   'shortName': 'Stansted',
#   'municipalityName': 'London',
#   'location': {'lat': 51.885, 'lon': 0.234999},
#   'countryCode': 'GB'},
#  {'icao': 'EGKB',
#   'iata': 'BQH',
#   'name': 'London Biggin Hill',
#   'shortName': 'Biggin Hill',
#   'municipalityName': 'London',
#   'location': {'lat': 51.3308, 'lon': 0.032499},
#   'countryCode': 'GB'},
#  {'icao': 'EGWU',
#   'iata': 'NHT',
#   'name': 'London RAF Northolt',
#   'shortName': 'RAF Northolt',
#   'municipalityName': 'London',
#   'location': {'lat': 51.553, 'lon': -0.418166},
#   'countryCode': 'GB'},
#  {'icao': 'FAEL',
#   'iata': 'ELS',
#   'name': 'East London Ben Schoeman',
#   'shortName': 'Ben Schoeman',
#   'municipalityName': 'East London',
#   'location': {'lat': -33.0356, 'lon': 27.8259},
#   'countryCode': 'ZA'},
#  {'icao': 'KGON',
#   'iata': 'GON',
#   'name': 'Groton (New London) Groton New London',
#   'shortName': 'Groton New London',
#   'municipalityName': 'Groton (New London)',
#   'location': {'lat': 41.3301, 'lon': -72.0451},
#   'countryCode': 'US'}]

# %%
pd.json_normalize(r_json['items'])
# Out:
#    icao iata                                   name          shortName  \
# 0  CYXU  YXU                                London              London
# 1  EGGW  LTN                           London Luton              Luton
# 2  EGKK  LGW                         London Gatwick            Gatwick
# 3  EGLC  LCY                            London City               City
# 4  EGLL  LHR                        London Heathrow           Heathrow
# 5  EGSS  STN                        London Stansted           Stansted
# 6  EGKB  BQH                     London Biggin Hill        Biggin Hill
# 7  EGWU  NHT                    London RAF Northolt       RAF Northolt
# 8  FAEL  ELS               East London Ben Schoeman       Ben Schoeman
# 9  KGON  GON  Groton (New London) Groton New London  Groton New London
#
#       municipalityName countryCode  location.lat  location.lon
# 0               London          CA       43.0356    -81.153900
# 1               London          GB       51.8747     -0.368333
# 2               London          GB       51.1481     -0.190277
# 3               London          GB       51.5053      0.055277
# 4               London          GB       51.4706     -0.461941
# 5               London          GB       51.8850      0.234999
# 6               London          GB       51.3308      0.032499
# 7               London          GB       51.5530     -0.418166
# 8          East London          ZA      -33.0356     27.825900
# 9  Groton (New London)          US       41.3301    -72.045100

# %%
icao_from = 'LEMD'
icao_to = 'EGKK'

url = f"https://aerodatabox.p.rapidapi.com/airports/icao/{icao_from}/distance-time/{icao_to}"

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'from': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid Adolfo Suárez –Barajas', 'shortName': 'Adolfo Suárez –Barajas', 'municipalityName': 'Madrid', 'location': {'lat': 40.4936, 'lon': -3.56676}, 'countryCode': 'ES'}, 'to': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London Gatwick', 'shortName': 'Gatwick', 'municipalityName': 'London', 'location': {'lat': 51.1481, 'lon': -0.190277}, 'countryCode': 'GB'}, 'greatCircleDistance': {'meter': 1212598.73, 'km': 1212.6, 'mile': 753.47, 'nm': 654.75, 'feet': 3978342.3}, 'approxFlightTime': '01:35:00'}

# %%
pd.json_normalize(response.json())
# Out:
#   approxFlightTime from.icao from.iata                      from.name  \
# 0         01:35:00      LEMD       MAD  Madrid Adolfo Suárez –Barajas
#
#            from.shortName from.municipalityName  from.location.lat  \
# 0  Adolfo Suárez –Barajas                Madrid            40.4936
#
#    from.location.lon from.countryCode to.icao  ... to.shortName  \
# 0           -3.56676               ES    EGKK  ...      Gatwick
#
#   to.municipalityName to.location.lat to.location.lon  to.countryCode  \
# 0              London         51.1481       -0.190277              GB
#
#    greatCircleDistance.meter greatCircleDistance.km  greatCircleDistance.mile  \
# 0                 1212598.73                 1212.6                    753.47
#
#    greatCircleDistance.nm  greatCircleDistance.feet
# 0                  654.75                 3978342.3
#
# [1 rows x 22 columns]

# %%
url = "https://aerodatabox.p.rapidapi.com/flights/%7BsearchBy%7D/KL1395/dates/2020-06-01/2020-06-15"
        


response = requests.get(url, headers=headers)

result = response.json()
result
# Out:
# {'message': 'This endpoint is disabled for your subscription'}

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/airports/icao/KLAX/time/local"

headers = {
    "X-RapidAPI-Key": "9613ca6ca5msh62659872159916fp1a0a2cjsndd9a3e6ff324",
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'time': {'utc': '2024-03-26 19:42Z', 'local': '2024-03-26 12:42-07:00'}, 'timeZoneId': 'America/Los_Angeles'}

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/airports/icao/EGSS/delays"

headers = {
    "X-RapidAPI-Key": "9613ca6ca5msh62659872159916fp1a0a2cjsndd9a3e6ff324",
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'airportIcao': 'EGSS', 'from': {'utc': '2024-03-26 17:43Z', 'local': '2024-03-26 17:43+00:00'}, 'to': {'utc': '2024-03-26 19:43Z', 'local': '2024-03-26 19:43+00:00'}, 'departuresDelayInformation': {'numTotal': 29, 'numQualifiedTotal': 29, 'numCancelled': 0, 'medianDelay': '00:00:00', 'delayIndex': 0.0}, 'arrivalsDelayInformation': {'numTotal': 28, 'numQualifiedTotal': 28, 'numCancelled': 0, 'medianDelay': '-00:05:00', 'delayIndex': 0.0}}

# %%
#define a function to put all the information together

def
